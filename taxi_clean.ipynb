# %% [markdown]
# # Taxi Trips in NYC Data Cleaning

# %% [markdown]
# This notebook contains all the code needed to clean the raw data from taxi_tripdata.csv and taxi_zones.csv to create the new, cleaned dataset taxi_clean.csv

# %% [markdown]
# ## Imports and Grabbing Data

# %%
import pandas as pd
import numpy as np

# %%
dtypes = {'VendorID': 'Int64', 'store_and_fwd_flag': 'str', 'RatecodeID': 'Int64', 'passenger_count': 'Int64', 'payment_type': 'Int64', 'trip_type': 'Int64'}
parse_dates = ['lpep_pickup_datetime', 'lpep_dropoff_datetime']
df = pd.read_csv('data/taxi_tripdata.csv', dtype=dtypes, parse_dates=parse_dates)

# %%
# First few rows of the raw data:
df.head(10)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         1  2021-07-01 00:30:52   2021-07-01 00:35:36                  N
# 1         2  2021-07-01 00:25:36   2021-07-01 01:01:31                  N
# 2         2  2021-07-01 00:05:58   2021-07-01 00:12:00                  N
# 3         2  2021-07-01 00:41:40   2021-07-01 00:47:23                  N
# 4         2  2021-07-01 00:51:32   2021-07-01 00:58:46                  N
# 5         1  2021-07-01 00:05:00   2021-07-01 00:11:50                  N
# 6         2  2021-07-01 00:57:14   2021-07-01 01:27:43                  N
# 7         2  2021-07-01 00:27:36   2021-07-01 00:32:35                  N
# 8         2  2021-07-01 00:29:09   2021-07-01 00:34:18                  N
# 9         2  2021-07-01 00:41:33   2021-07-01 00:49:24                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            74           168                1           1.20
# 1           1           116           265                2          13.69
# 2           1            97            33                1           0.95
# 3           1            74            42                1           1.24
# 4           1            42           244                1           1.10
# 5           1            24           239                1           1.90
# 6           1            75           243                1           0.00
# 7           1            82            82                1           0.66
# 8           1            74            42                1           1.72
# 9           1            41            42                1           1.37
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          6.0   0.50      0.5        0.00           0.0        NaN
# 1         42.0   0.50      0.5        0.00           0.0        NaN
# 2          6.5   0.50      0.5        2.34           0.0        NaN
# 3          6.5   0.50      0.5        0.00           0.0        NaN
# 4          7.0   0.50      0.5        0.00           0.0        NaN
# 5          8.0   3.25      0.5        3.00           0.0        NaN
# 6         17.5   0.50      0.5        0.00           0.0        NaN
# 7          5.0   0.50      0.5        0.00           0.0        NaN
# 8          7.0   0.50      0.5        2.08           0.0        NaN
# 9          7.5   0.50      0.5        0.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3          7.30             2          1
# 1                    0.3         43.30             2          1
# 2                    0.3         10.14             1          1
# 3                    0.3          7.80             2          1
# 4                    0.3          8.30             2          1
# 5                    0.3         15.05             1          1
# 6                    0.3         18.80             2          1
# 7                    0.3          6.30             2          1
# 8                    0.3         10.38             1          1
# 9                    0.3          8.80             2          1
#
#    congestion_surcharge
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00
# 5                  2.75
# 6                  0.00
# 7                  0.00
# 8                  0.00
# 9                  0.00

# %% [markdown]
# ## Dropping Unnecessary Columns
# The following columns will not be used in our analysis and will be dropped: `ehail_fee`

# %%
df = df.drop('ehail_fee', axis=1)

# %% [markdown]
# ## Remove Invalid Rows

# %% [markdown]
# Remove rows where the `trip_distance` is 0.

# %%
print('Remove ' + str(len(df[df['trip_distance'] == 0])) + ' rows with a trip_distance of 0')
df = df[df['trip_distance'] > 0]
# Out:
# Remove 3455 rows with a trip_distance of 0

# %% [markdown]
# ## Adding New Columns

# %% [markdown]
# We will begin by adding the following columns to make it easier to analyze the times:
# - day of the week for the trip (0 = Monday...6 = Sunday)
# - day of the month for the trip
# - time of the day for the trip

# %%
df['day_of_week'] = df['lpep_pickup_datetime'].dt.dayofweek
df['day_of_month'] = df['lpep_pickup_datetime'].dt.day
df['hour_of_day'] = df['lpep_pickup_datetime'].dt.hour
df['trip_duration'] = round((df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']).dt.total_seconds())
df[['lpep_pickup_datetime', 'lpep_dropoff_datetime', 'day_of_week', 'day_of_month', 'hour_of_day', 'trip_duration']]
# Out:
#       lpep_pickup_datetime lpep_dropoff_datetime  day_of_week  day_of_month  \
# 0      2021-07-01 00:30:52   2021-07-01 00:35:36            3             1
# 1      2021-07-01 00:25:36   2021-07-01 01:01:31            3             1
# 2      2021-07-01 00:05:58   2021-07-01 00:12:00            3             1
# 3      2021-07-01 00:41:40   2021-07-01 00:47:23            3             1
# 4      2021-07-01 00:51:32   2021-07-01 00:58:46            3             1
# ...                    ...                   ...          ...           ...
# 83686  2021-07-02 07:59:00   2021-07-02 08:33:00            4             2
# 83687  2021-07-02 07:02:00   2021-07-02 07:18:00            4             2
# 83688  2021-07-02 07:53:00   2021-07-02 08:15:00            4             2
# 83689  2021-07-02 07:58:00   2021-07-02 08:30:00            4             2
# 83690  2021-07-02 07:00:00   2021-07-02 07:26:00            4             2
#
#        hour_of_day  trip_duration
# 0                0          284.0
# 1                0         2155.0
# 2                0          362.0
# 3                0          343.0
# 4                0          434.0
# ...            ...            ...
# 83686            7         2040.0
# 83687            7          960.0
# 83688            7         1320.0
# 83689            7         1920.0
# 83690            7         1560.0
#
# [80236 rows x 6 columns]

# %% [markdown]
# Then, we'll add a column for the total fare without the tip (`total_amount` - `tip_amount`) and the fare per distance ($/mile not including the tip amount).

# %%
df['total_without_tip'] = round(df['total_amount'] - df['tip_amount'], 2)
df['fare_per_mile'] = round(df['total_without_tip'] / df['trip_distance'], 2)
df[['tip_amount', 'total_amount', 'total_without_tip', 'trip_distance', 'fare_per_mile']]
# Out:
#        tip_amount  total_amount  total_without_tip  trip_distance  \
# 0            0.00          7.30               7.30           1.20
# 1            0.00         43.30              43.30          13.69
# 2            2.34         10.14               7.80           0.95
# 3            0.00          7.80               7.80           1.24
# 4            0.00          8.30               8.30           1.10
# ...           ...           ...                ...            ...
# 83686        0.00         59.84              59.84          18.04
# 83687        3.66         25.87              22.21           5.56
# 83688        0.00         22.75              22.75           5.13
# 83689        0.00         54.12              54.12          12.58
# 83690        0.00         48.89              48.89          11.32
#
#        fare_per_mile
# 0               6.08
# 1               3.16
# 2               8.21
# 3               6.29
# 4               7.55
# ...              ...
# 83686           3.32
# 83687           3.99
# 83688           4.43
# 83689           4.30
# 83690           4.32
#
# [80236 rows x 5 columns]

# %% [markdown]
# For potential next steps, we would like to incorporate the data for taxi zones and performa analysis regarding location.

# %% [markdown]
# ## Save Data

# %%
df.to_csv('data/taxi_clean.csv', index=False)
