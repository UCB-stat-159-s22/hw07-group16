# %% [markdown]
# # Taxi Trips in NYC Data Cleaning

# %% [markdown]
# This notebook contains all the code needed to clean the raw data from taxi_tripdata.csv and taxi_zones.csv to create the new, cleaned dataset taxi_clean.csv

# %% [markdown]
# ## Imports and Grabbing Data

# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
dtypes = {'VendorID': 'Int64', 'store_and_fwd_flag': 'str', 'RatecodeID': 'Int64', 'passenger_count': 'Int64', 'payment_type': 'Int64', 'trip_type': 'Int64'}
parse_dates = ['lpep_pickup_datetime', 'lpep_dropoff_datetime']
df = pd.read_csv('data/taxi_tripdata.csv', dtype=dtypes, parse_dates=parse_dates)

# %%
# First few rows of the raw data:
df.head(10)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         1  2021-07-01 00:30:52   2021-07-01 00:35:36                  N
# 1         2  2021-07-01 00:25:36   2021-07-01 01:01:31                  N
# 2         2  2021-07-01 00:05:58   2021-07-01 00:12:00                  N
# 3         2  2021-07-01 00:41:40   2021-07-01 00:47:23                  N
# 4         2  2021-07-01 00:51:32   2021-07-01 00:58:46                  N
# 5         1  2021-07-01 00:05:00   2021-07-01 00:11:50                  N
# 6         2  2021-07-01 00:57:14   2021-07-01 01:27:43                  N
# 7         2  2021-07-01 00:27:36   2021-07-01 00:32:35                  N
# 8         2  2021-07-01 00:29:09   2021-07-01 00:34:18                  N
# 9         2  2021-07-01 00:41:33   2021-07-01 00:49:24                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            74           168                1           1.20
# 1           1           116           265                2          13.69
# 2           1            97            33                1           0.95
# 3           1            74            42                1           1.24
# 4           1            42           244                1           1.10
# 5           1            24           239                1           1.90
# 6           1            75           243                1           0.00
# 7           1            82            82                1           0.66
# 8           1            74            42                1           1.72
# 9           1            41            42                1           1.37
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          6.0   0.50      0.5        0.00           0.0        NaN
# 1         42.0   0.50      0.5        0.00           0.0        NaN
# 2          6.5   0.50      0.5        2.34           0.0        NaN
# 3          6.5   0.50      0.5        0.00           0.0        NaN
# 4          7.0   0.50      0.5        0.00           0.0        NaN
# 5          8.0   3.25      0.5        3.00           0.0        NaN
# 6         17.5   0.50      0.5        0.00           0.0        NaN
# 7          5.0   0.50      0.5        0.00           0.0        NaN
# 8          7.0   0.50      0.5        2.08           0.0        NaN
# 9          7.5   0.50      0.5        0.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3          7.30             2          1
# 1                    0.3         43.30             2          1
# 2                    0.3         10.14             1          1
# 3                    0.3          7.80             2          1
# 4                    0.3          8.30             2          1
# 5                    0.3         15.05             1          1
# 6                    0.3         18.80             2          1
# 7                    0.3          6.30             2          1
# 8                    0.3         10.38             1          1
# 9                    0.3          8.80             2          1
#
#    congestion_surcharge
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00
# 5                  2.75
# 6                  0.00
# 7                  0.00
# 8                  0.00
# 9                  0.00

# %% [markdown]
# ## Dropping Unnecessary Columns
# Removing the `ehail_fee` column.

# %%
df_drops = df.drop('ehail_fee', axis=1)
df_drops.head(10)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         1  2021-07-01 00:30:52   2021-07-01 00:35:36                  N
# 1         2  2021-07-01 00:25:36   2021-07-01 01:01:31                  N
# 2         2  2021-07-01 00:05:58   2021-07-01 00:12:00                  N
# 3         2  2021-07-01 00:41:40   2021-07-01 00:47:23                  N
# 4         2  2021-07-01 00:51:32   2021-07-01 00:58:46                  N
# 5         1  2021-07-01 00:05:00   2021-07-01 00:11:50                  N
# 6         2  2021-07-01 00:57:14   2021-07-01 01:27:43                  N
# 7         2  2021-07-01 00:27:36   2021-07-01 00:32:35                  N
# 8         2  2021-07-01 00:29:09   2021-07-01 00:34:18                  N
# 9         2  2021-07-01 00:41:33   2021-07-01 00:49:24                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            74           168                1           1.20
# 1           1           116           265                2          13.69
# 2           1            97            33                1           0.95
# 3           1            74            42                1           1.24
# 4           1            42           244                1           1.10
# 5           1            24           239                1           1.90
# 6           1            75           243                1           0.00
# 7           1            82            82                1           0.66
# 8           1            74            42                1           1.72
# 9           1            41            42                1           1.37
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          6.0   0.50      0.5        0.00           0.0
# 1         42.0   0.50      0.5        0.00           0.0
# 2          6.5   0.50      0.5        2.34           0.0
# 3          6.5   0.50      0.5        0.00           0.0
# 4          7.0   0.50      0.5        0.00           0.0
# 5          8.0   3.25      0.5        3.00           0.0
# 6         17.5   0.50      0.5        0.00           0.0
# 7          5.0   0.50      0.5        0.00           0.0
# 8          7.0   0.50      0.5        2.08           0.0
# 9          7.5   0.50      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3          7.30             2          1
# 1                    0.3         43.30             2          1
# 2                    0.3         10.14             1          1
# 3                    0.3          7.80             2          1
# 4                    0.3          8.30             2          1
# 5                    0.3         15.05             1          1
# 6                    0.3         18.80             2          1
# 7                    0.3          6.30             2          1
# 8                    0.3         10.38             1          1
# 9                    0.3          8.80             2          1
#
#    congestion_surcharge
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00
# 5                  2.75
# 6                  0.00
# 7                  0.00
# 8                  0.00
# 9                  0.00

# %% [markdown]
# ## Remove Invalid Rows

# %% [markdown]
# Remove rows where the `trip_distance` is 0, or the `tip_amount` is negative. Because the majority of the data involves trips in July, we decided to remove any outlier data from other months.

# %%
print('Remove ' + str(len(df_drops[df_drops['trip_distance'] == 0])) + ' rows with a trip_distance of 0')
df_rev1 = df_drops[df_drops['trip_distance'] > 0]
# Out:
# Remove 3455 rows with a trip_distance of 0

# %%
print('Remove ' + str(len(df_rev1[df_rev1['tip_amount'] < 0])) + ' row(s) with a negative tip')
df_rev2 = df_rev1[df_rev1['tip_amount'] >= 0]
# Out:
# Remove 1 row(s) with a negative tip

# %%
print('Remove ' + str(len(df_rev2[df_rev2['lpep_pickup_datetime'].dt.month != 7])) + ' rows for trips not in July')
df_rev3 = df_rev2[df_rev2['lpep_pickup_datetime'].dt.month == 7]
# Out:
# Remove 16 rows for trips not in July

# %%
print('Remove ' + str(len(df_rev3[df_rev3['fare_amount'] <= 0])) + ' rows with a negative fare')
df_rev4 = df_rev3[df_rev3['fare_amount'] > 0]
# Out:
# Remove 249 rows with a negative fare

# %% [markdown]
# ## Adding New Columns

# %% [markdown]
# We will begin by adding the following columns to make it easier to analyze the times:
# - day of the week for the trip (0 = Monday...6 = Sunday)
# - day of the month for the trip
# - time of the day for the trip

# %%
df_add = df_rev4.copy()
df_add['day_of_week'] = df_add['lpep_pickup_datetime'].dt.dayofweek
df_add['day_of_month'] = df_add['lpep_pickup_datetime'].dt.day
df_add['hour_of_day'] = df_add['lpep_pickup_datetime'].dt.hour
df_add['trip_duration'] = round((df_add['lpep_dropoff_datetime'] - df_add['lpep_pickup_datetime']).dt.total_seconds())
df_add[['lpep_pickup_datetime', 'lpep_dropoff_datetime', 'day_of_week', 'day_of_month', 'hour_of_day', 'trip_duration']]
# Out:
#       lpep_pickup_datetime lpep_dropoff_datetime  day_of_week  day_of_month  \
# 0      2021-07-01 00:30:52   2021-07-01 00:35:36            3             1
# 1      2021-07-01 00:25:36   2021-07-01 01:01:31            3             1
# 2      2021-07-01 00:05:58   2021-07-01 00:12:00            3             1
# 3      2021-07-01 00:41:40   2021-07-01 00:47:23            3             1
# 4      2021-07-01 00:51:32   2021-07-01 00:58:46            3             1
# ...                    ...                   ...          ...           ...
# 83686  2021-07-02 07:59:00   2021-07-02 08:33:00            4             2
# 83687  2021-07-02 07:02:00   2021-07-02 07:18:00            4             2
# 83688  2021-07-02 07:53:00   2021-07-02 08:15:00            4             2
# 83689  2021-07-02 07:58:00   2021-07-02 08:30:00            4             2
# 83690  2021-07-02 07:00:00   2021-07-02 07:26:00            4             2
#
#        hour_of_day  trip_duration
# 0                0          284.0
# 1                0         2155.0
# 2                0          362.0
# 3                0          343.0
# 4                0          434.0
# ...            ...            ...
# 83686            7         2040.0
# 83687            7          960.0
# 83688            7         1320.0
# 83689            7         1920.0
# 83690            7         1560.0
#
# [79970 rows x 6 columns]

# %% [markdown]
# Then, we'll add a column for the total fare without the tip (`total_amount` - `tip_amount`) and the fare per distance ($/mile not including the tip amount).

# %%
df_add['total_without_tip'] = round(df_add['total_amount'] - df_add['tip_amount'], 2)
df_add['fare_per_mile'] = round(df_add['total_without_tip'] / df_add['trip_distance'], 2)
df_add[['tip_amount', 'total_amount', 'total_without_tip', 'trip_distance', 'fare_per_mile']]
# Out:
#        tip_amount  total_amount  total_without_tip  trip_distance  \
# 0            0.00          7.30               7.30           1.20
# 1            0.00         43.30              43.30          13.69
# 2            2.34         10.14               7.80           0.95
# 3            0.00          7.80               7.80           1.24
# 4            0.00          8.30               8.30           1.10
# ...           ...           ...                ...            ...
# 83686        0.00         59.84              59.84          18.04
# 83687        3.66         25.87              22.21           5.56
# 83688        0.00         22.75              22.75           5.13
# 83689        0.00         54.12              54.12          12.58
# 83690        0.00         48.89              48.89          11.32
#
#        fare_per_mile
# 0               6.08
# 1               3.16
# 2               8.21
# 3               6.29
# 4               7.55
# ...              ...
# 83686           3.32
# 83687           3.99
# 83688           4.43
# 83689           4.30
# 83690           4.32
#
# [79970 rows x 5 columns]

# %% [markdown]
# ## Location Data

# %%
taxi_zones = pd.read_csv('data/taxi_zones.csv')
taxi_zones.head()
# Out:
#    OBJECTID  Shape_Leng                                           the_geom  \
# 0         1    0.116357  MULTIPOLYGON (((-74.18445299999996 40.69499599...
# 1         2    0.433470  MULTIPOLYGON (((-73.82337597260663 40.63898704...
# 2         3    0.084341  MULTIPOLYGON (((-73.84792614099985 40.87134223...
# 3         4    0.043567  MULTIPOLYGON (((-73.97177410965318 40.72582128...
# 4         5    0.092146  MULTIPOLYGON (((-74.17421738099989 40.56256808...
#
#    Shape_Area                     zone  LocationID        borough
# 0    0.000782           Newark Airport           1            EWR
# 1    0.004866              Jamaica Bay           2         Queens
# 2    0.000314  Allerton/Pelham Gardens           3          Bronx
# 3    0.000112            Alphabet City           4      Manhattan
# 4    0.000498            Arden Heights           5  Staten Island

# %%
taxi_zones_less = taxi_zones[['the_geom', 'LocationID', 'zone', 'borough']]
pickup_dict = {'the_geom':'PUGeom', 'zone': 'PUZone', 'borough': 'PUBorough'}
dropoff_dict = {'the_geom':'DOGeom', 'zone': 'DOZone', 'borough': 'DOBorough'}
df_pickups = df_add.merge(right=taxi_zones_less, left_on='PULocationID', right_on='LocationID').drop(
    'LocationID', axis=1).rename(pickup_dict, axis='columns')
df_all_geoms = df_pickups.merge(right=taxi_zones_less, left_on='DOLocationID', right_on='LocationID').drop(
    'LocationID', axis=1).rename(dropoff_dict, axis='columns')
df_all_geoms
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             1  2021-07-01 00:30:52   2021-07-01 00:35:36                  N
# 1             2  2021-07-01 07:44:32   2021-07-01 07:50:42                  N
# 2             2  2021-07-01 17:37:32   2021-07-01 18:00:45                  N
# 3             2  2021-07-02 06:33:23   2021-07-02 06:38:04                  N
# 4             2  2021-07-02 18:48:40   2021-07-02 18:56:17                  N
# ...         ...                  ...                   ...                ...
# 79847         2  2021-07-27 19:28:52   2021-07-27 20:10:02                  N
# 79848         2  2021-07-29 19:23:15   2021-07-29 20:19:28                  N
# 79849         2  2021-07-07 15:43:32   2021-07-07 17:28:21                  N
# 79850         2  2021-07-27 22:50:07   2021-07-27 22:56:26                  N
# 79851      <NA>  2021-07-23 22:52:00   2021-07-23 23:44:00                NaN
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0               1            74           168                1           1.20
# 1               1            74           168                1           1.57
# 2               1            74           168                1           1.31
# 3               1            74           168                1           1.97
# 4               1            74           168                1           1.43
# ...           ...           ...           ...              ...            ...
# 79847           1            14             6                1          28.90
# 79848           1            54             6                1          26.53
# 79849           1            14            99                1          15.62
# 79850           1             5            99                1           1.58
# 79851        <NA>           177           176             <NA>          17.26
#
#        fare_amount  ...  hour_of_day  trip_duration  total_without_tip  \
# 0             6.00  ...            0          284.0               7.30
# 1             7.00  ...            7          370.0               7.80
# 2            14.00  ...           17         1393.0              15.80
# 3             7.50  ...            6          281.0               8.30
# 4             7.00  ...           18          457.0               8.80
# ...            ...  ...          ...            ...                ...
# 79847        76.50  ...           19         2470.0              84.85
# 79848        75.50  ...           19         3373.0              83.85
# 79849        77.50  ...           15         6289.0              84.85
# 79850         7.50  ...           22          379.0               8.80
# 79851        61.25  ...           22         3120.0              68.10
#
#        fare_per_mile                                             PUGeom  \
# 0               6.08  MULTIPOLYGON (((-73.93380589881859 40.81651249...
# 1               4.97  MULTIPOLYGON (((-73.93380589881859 40.81651249...
# 2              12.06  MULTIPOLYGON (((-73.93380589881859 40.81651249...
# 3               4.21  MULTIPOLYGON (((-73.93380589881859 40.81651249...
# 4               6.15  MULTIPOLYGON (((-73.93380589881859 40.81651249...
# ...              ...                                                ...
# 79847           2.94  MULTIPOLYGON (((-74.03407329297129 40.64431393...
# 79848           3.16  MULTIPOLYGON (((-74.00174362072502 40.69240674...
# 79849           5.43  MULTIPOLYGON (((-74.03407329297129 40.64431393...
# 79850           5.57  MULTIPOLYGON (((-74.17421738099989 40.56256808...
# 79851           3.95  MULTIPOLYGON (((-73.90287079599995 40.67863141...
#
#                   PUZone      PUBorough  \
# 0      East Harlem North      Manhattan
# 1      East Harlem North      Manhattan
# 2      East Harlem North      Manhattan
# 3      East Harlem North      Manhattan
# 4      East Harlem North      Manhattan
# ...                  ...            ...
# 79847          Bay Ridge       Brooklyn
# 79848    Columbia Street       Brooklyn
# 79849          Bay Ridge       Brooklyn
# 79850      Arden Heights  Staten Island
# 79851         Ocean Hill       Brooklyn
#
#                                                   DOGeom  \
# 0      MULTIPOLYGON (((-73.92480953899991 40.81565901...
# 1      MULTIPOLYGON (((-73.92480953899991 40.81565901...
# 2      MULTIPOLYGON (((-73.92480953899991 40.81565901...
# 3      MULTIPOLYGON (((-73.92480953899991 40.81565901...
# 4      MULTIPOLYGON (((-73.92480953899991 40.81565901...
# ...                                                  ...
# 79847  MULTIPOLYGON (((-74.06367318899999 40.60219816...
# 79848  MULTIPOLYGON (((-74.06367318899999 40.60219816...
# 79849  MULTIPOLYGON (((-74.16842916199994 40.58649792...
# 79850  MULTIPOLYGON (((-74.16842916199994 40.58649792...
# 79851  MULTIPOLYGON (((-74.12187198599999 40.57510757...
#
#                         DOZone      DOBorough
# 0       Mott Haven/Port Morris          Bronx
# 1       Mott Haven/Port Morris          Bronx
# 2       Mott Haven/Port Morris          Bronx
# 3       Mott Haven/Port Morris          Bronx
# 4       Mott Haven/Port Morris          Bronx
# ...                        ...            ...
# 79847  Arrochar/Fort Wadsworth  Staten Island
# 79848  Arrochar/Fort Wadsworth  Staten Island
# 79849          Freshkills Park  Staten Island
# 79850          Freshkills Park  Staten Island
# 79851                  Oakwood  Staten Island
#
# [79852 rows x 31 columns]

# %% [markdown]
# ## Save Data

# %%
df_add.to_csv('data/taxi_clean.csv', index=False)
